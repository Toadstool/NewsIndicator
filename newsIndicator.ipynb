# %% [markdown]
# Wskaźnik newsów
# ===============

# %%
import sharePrice as sp
import matplotlib.pyplot as plt

data =sp. getWeekly('PKOBP')
plt.plot(list(map(lambda x: x[0],data)),list(map(lambda x: x[1],data)))
plt.show()
