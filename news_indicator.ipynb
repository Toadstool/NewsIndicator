# %% [markdown]
# Wskaźnik newsów
# ===============

# %%
import share_price as sp
import matplotlib.pyplot as plt

data =sp.getLastWeekIntraday('PKOBP')
plt.plot(list(map(lambda x: x[0],data)),list(map(lambda x: x[1],data)))
plt.show()
